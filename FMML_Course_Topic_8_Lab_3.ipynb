# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyanarayanabathula/FMML_COURSE_ASSGINMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-10 06:15:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   174MB/s    in 0.4s
#
# 2023-06-10 06:16:01 (174 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5319    1301.3568v3  We introduce a new method for training deep Bo...  stat
# 19570   0907.5598v2  We consider a sequence of repeated interaction...    cs
# 16814  1706.03367v1  Restricted non-monotonicity has been shown ben...    cs
# 40490   1203.5446v1  This paper proposes to use a rather new modell...  stat
# 21803  1604.03492v1  In recent years, structured matrix recovery pr...  stat
# ...             ...                                                ...   ...
# 22375  1605.00513v1  Distributional (or distribution-valued) data a...  stat
# 1435   1711.06379v2  We develop a set of methods to improve on the ...    cs
# 21574   1103.4023v1  Gaussian Process (GP) models are often used as...  stat
# 29385  1709.02549v1  In this research work, a novel framework is pr...    cs
# 6443   1702.01935v1  As enjoying the closed form solution, least sq...    cs
#
#                                                    title  year  \
# 5319   Joint Training Deep Boltzmann Machines for Cla...  2013
# 19570   Convergence of Expected Utility for Universal AI  2009
# 16814  A Full Non-Monotonic Transition System for Unr...  2017
# 40490  A Bayesian Model Committee Approach to Forecas...  2012
# 21803  Structured Matrix Recovery via the Generalized...  2016
# ...                                                  ...   ...
# 22375  Fuzzy clustering of distribution-valued data u...  2016
# 1435   Improvements to context based self-supervised ...  2017
# 21574     Additive Kernels for Gaussian Process Modeling  2011
# 29385  A Novel Low-Complexity Framework in Ultra-Wide...  2017
# 6443   Sparse Algorithm for Robust LSSVM in Primal Space  2017
#
#                                                 keywords
# 5319   [introduce, boltzmann, classification, simulta...
# 19570  [interactions, environment, uncertainty, envir...
# 16814  [restricted, monotonicity, beneficial, project...
# 40490  [modelling, radiation, forecasting, forecastin...
# 21803  [structured, considerable, attention, applicat...
# ...                                                  ...
# 22375  [distributional, distribution, considered, rea...
# 1435   [supervised, arrangement, chromatic, aberratio...
# 21574  [mathematical, approximations, computationally...
# 29385  [framework, efficient, successor, traditional,...
# 6443   [classification, regression, comparable, perfo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5319     [introduce, boltzmann, classification, simulta...
# 19570    [interactions, environment, uncertainty, envir...
# 16814    [restricted, monotonicity, beneficial, project...
# 40490    [modelling, radiation, forecasting, forecastin...
# 21803    [structured, considerable, attention, applicat...
#                                ...
# 4334     [understanding, important, applications, under...
# 3221     [incorporating, interpretable, dimensional, wi...
# 22252    [eigenvectors, modularity, uncentered, develop...
# 6293     [presented, straightforward, application, proc...
# 38058    [background, potential, crowdsource, epidemics...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8900 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1d297ba9-d756-4a92-9c59-f5d317c1c2d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d297ba9-d756-4a92-9c59-f5d317c1c2d0")) {                    Plotly.newPlot(                        "1d297ba9-d756-4a92-9c59-f5d317c1c2d0",                        [{"x":["generalized","simultaneously","approximation","parameters","approximately","inference","pseudolikelihood","generative","boltzmann","outperforms","resulting","classification","approximate","procedure","technique","interpreted","prediction","variational","recurrent","competitively","introduce","unbounded","computable","universal","computational","hypotheses","plausible","convergence","assumptions","distribution","environment","functions","interactions","interaction","uncertainty","probability","algorithm","posterior","monotonicity","monotonic","covington","erroneous","restricted","information","exploration","projective","languages","beneficial","transition","dependency","unrestricted","approximations","experiments","decisions","radiation","horizontal","benchmarked","improvement","committee","persistence","autoregressive","measurements","comparisons","modelling","forecasting","predictions","respective","irradiance","illustrate","theoretical","development","unitarily","structures","considerable","characterized","structured","expressed","invariant","estimation","underlying","attention","recommender","asymptotic","structure","geometric","generally","practical","applications","succinctly","euclidean","interested","recognition","surveillance","suspicious","extensive","intelligent","acquiring","considered","traditional","respectively","coordinates","performance","benchmark","characteristics","corresponding","computation","evaluating","framework","empirical","decomposition","cooperative","effectively","dimensional","different","algorithms","conventional","simulation","optimization","evaluation","constructs","constructing","sacrificing","significantly","resources","alleviate","surrogate","enhancing","solutions","considering","adaptively","following","experimental","desirable","demonstrate","similarity","transformation","robustness","constrained","characteristic","advancement","condition","artificial","implementation","environmental","communication","addressed","techniques","therefore","relationship","efficiently","constructed","connection","selection","highlight","independently","estimates","particular","attractive","exploitation","significant","sequential","successful","developing","reinforcement","extension","comparison","supervised","developed","contextual","approaches","converging","understand","established","challenge","prevented","excellent","correlation","investigated","combination","predictive","importance","simulations","application","illustrated","arbitrary","appearance","retrospective","typically","accessible","weighting","interpretation","analytically","properties","unfortunately","interpretability","associated","regularization","iterative","consistency","statistics"],"y":[69,101,115,267,21,223,0,135,13,246,162,526,117,111,236,28,229,62,159,6,343,14,15,40,308,29,21,115,63,198,119,215,67,88,69,148,805,57,5,15,2,5,30,720,60,5,96,13,22,42,5,39,628,56,4,8,9,130,5,1,5,56,31,35,16,91,22,1,75,162,138,1,123,34,32,107,38,60,204,110,192,22,22,329,65,67,127,453,1,29,24,395,33,3,162,53,11,129,190,94,14,888,195,109,153,141,55,527,158,69,9,105,213,784,609,95,70,302,261,17,45,15,276,83,29,6,16,131,80,20,80,364,30,574,145,64,118,48,21,8,46,138,132,13,70,45,374,163,78,146,46,41,171,25,45,54,277,23,16,227,71,67,61,103,82,154,196,201,62,415,7,66,50,158,5,26,72,35,151,74,98,41,231,15,89,91,4,104,20,21,75,9,198,30,21,115,89,68,56,79],"type":"bar"},{"x":["generalized","simultaneously","approximation","p ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>Enhancing</span> <span style=''>Person</span> <span style=''>Re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Self</span> <span style=''>trained</span> <span style=''>Subspace</span> <br/><br/><span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>promising</span> <span style=''>progress</span> <span style=''>made</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>person</span> <span style=''>re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>(re</span> <span style=''>ID)</span> <span style=''>remains</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.491183879093199);'>challenging</span> <span style=''>task</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.6122448979591836);'>variations</span> <span style=''>in</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>appearances</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3390264730999146);'>different</span> <span style=''>camera</span> <span style=''>views</span> <span style=''>For</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.491183879093199);'>challenging</span> <span style=''>problem</span> <span style=''>a</span> <span style=''>large</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>setting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>access</span> <span style=''>to</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>data</span> <span style=''>However</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottleneck</span> <span style=''>for</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>re</span> <span style=''>ID</span> <span style=''>is</span> <span style=''>the</span> <span style=''>limited</span> <span style='background-color:rgba(0, 255, 0, 0.5882352941176471);'>availability</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>self</span> <span style=''>trained</span> <span style=''>subspace</span> <span style=''>learning</span> <span style=''>paradigm</span> <span style=''>for</span> <span style=''>person</span> <span style=''>re</span> <span style=''>ID</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectively</span> <span style=''>utilizes</span> <span style=''>both</span> <span style=''>labeled</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-co ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergence</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Landscape</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Loss</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>(loss)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>powerhouse</span> <span style=''>for</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>at</span> <span style=''>least</span> <span style=''>two</span> <span style=''>decades</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attracted</span> <span style=''>fast</span> <span style=''>growing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interests</span> <span style=''>recently</span> <span style=''>due</span> <span style=''>to</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>such</span> <span style=''>as</span> <span style=''>superior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>their</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterparts</span> <span style=''>The</span> <span style=''>main</span> <span style=''>obstacle</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>in</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>issues</span> <span style=''>for</span> <span style=''>some</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>M</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style=''>optimal</span> <span style=''>with</span> <span style=''>linear</span> <span style=''>rate</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>property</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Brenier</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transportation</span> <span style=''>between</span> <span style=''>a</span> <span style=''>quasi</span> <span style=''>discrete</span> <span style=''>measure</span> <span style=''>and</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>measure</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Correctly</span> <span style='background-color:rgba(255, 0, 0, 0.43842364532019695);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrepancy</span> <span style=''>between</span> <span style=''>two</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.36231884057971014);'>distributions</span> <span style=''>has</span> <span style=''>always</span> <span style=''>been</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>task</span> <span style=''>in</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Recently</span> <span style=''>Cuturi</span> <span style=''>proposed</span> <span style=''>the</span> <span style=''>Sinkhorn</span> <span style=''>distance</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transport</span> <span style=''>cost</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.36231884057971014);'>distributions</span> <span style=''>as</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>describe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrepancy</span> <span style=''>Although</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>adopted</span> <span style=''>in</span> <span style=''>various</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>(eg</span> <span style=''>in</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.43523316062176165);'>Processing</span> <span style=''>and</span> <span style=''>Computer</span> <span style=''>Vision)</span> <span style=''>since</span> <span style=''>then</span> <span style=''>the</span> <span style=''>Sinkhorn</span> <span style=''>distance</span> <span style=''>also</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>two</span> <span style=''>unnegligible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>The</span> <span style=''>first</span> <span style=''>one</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Sinkhorn</span> <span style=''>distance</span> <span style=''>only</span> <span style=''>gives</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.52);'>Wasserstein</span> <span style=''>distance</span> <span style=''>the</span> <span style=''>second</span> <span style=''>one</span> <span style=''>is</span> <span style=''>the</span> <span style=''>divide</span> <span style=''>by</span> <span style=''>zero</span> <span style=''>problem</span> <span style=''>which</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Task</span> <span style=''>Multiple</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relationship</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>learns</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>weights</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>infer</span> <span style=''>this</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>in</span> <span style=''>the</span> <span style=''>textitRKHS</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style=''>given</span> <span style=''>base</span> <span style=''>kernels</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>called</span> <span style=''>textitMulti</span> <span style=''>Task</span> <span style=''>Multiple</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relationship</span> <span style=''>Learning</span> <span style=''>(textitMK</span> <span style=''>MTRL)</span> <span style=''>which</span> <span style=''>models</span> <span style=''>the</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>matrix</span> <span style=''>from</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>latent</span> <span style=''>feature</span> <span style=''>spaces</span> <span style=''>of</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>base</span> <span style=''>kernels</span> <span style=''>Unlike</span> <span style=''>in</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>allows</span> <span style=''>one</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>learning</span> <span style=''>several</span> <span style=''>related</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>le ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0649536045681656)
# 	knowledge (0.12348322626695217)
# 	challenging (0.10563882940756603)
# 	segmentation (0.07458957887223412)
# 	architecture (0.09421841541755889)
# 	detection (0.11670235546038545)
# 	information (0.2569593147751606)
# 	different (0.2798001427551749)
# 	recognition (0.1409707351891506)
# 	convolutional (0.14168451106352606)
#
# Some Statistics words are:
# 	stochastic (0.13113113113113112)
# 	statistical (0.14764764764764765)
# 	theoretical (0.15215215215215216)
# 	estimation (0.16816816816816818)
# 	algorithm (0.38738738738738737)
# 	variables (0.14514514514514515)
# 	distribution (0.17517517517517517)
# 	inference (0.19269269269269268)
# 	dimensional (0.1891891891891892)
# 	regression (0.17717717717717718)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ca5b3522-7aa2-4844-9f5d-49071c256444" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca5b3522-7aa2-4844-9f5d-49071c256444")) {                    Plotly.newPlot(                        "ca5b3522-7aa2-4844-9f5d-49071c256444",                        [{"x":["generalized","simultaneously","approximation","parameters","approximately","inference","pseudolikelihood","generative","boltzmann","outperforms","resulting","classification","approximate","procedure","technique","interpreted","prediction","variational","recurrent","competitively","introduce","unbounded","computable","universal","computational","hypotheses","plausible","convergence","assumptions","distribution","environment","functions","interactions","interaction","uncertainty","probability","algorithm","posterior","monotonicity","monotonic","covington","erroneous","restricted","information","exploration","projective","languages","beneficial","transition","dependency","unrestricted","approximations","experiments","decisions","radiation","horizontal","benchmarked","improvement","committee","persistence","autoregressive","measurements","comparisons","modelling","forecasting","predictions","respective","irradiance","illustrate","theoretical","development","unitarily","structures","considerable","characterized","structured","expressed","invariant","estimation","underlying","attention","recommender","asymptotic","structure","geometric","generally","practical","applications","succinctly","euclidean","interested","recognition","surveillance","suspicious","extensive","intelligent","acquiring","considered","traditional","respectively","coordinates","performance","benchmark","characteristics","corresponding","computation","evaluating","framework","empirical","decomposition","cooperative","effectively","dimensional","different","algorithms","conventional","simulation","optimization","evaluation","constructs","constructing","sacrificing","significantly","resources","alleviate","surrogate","enhancing","solutions","considering","adaptively","following","experimental","desirable","demonstrate","similarity","transformation","robustness","constrained","characteristic","advancement","condition","artificial","implementation","environmental","communication","addressed","techniques","therefore","relationship","efficiently","constructed","connection","selection","highlight","independently","estimates","particular","attractive","exploitation","significant","sequential","successful","developing","reinforcement","extension","comparison","supervised","developed","contextual","approaches","converging","understand","established","challenge","prevented","excellent","correlation","investigated","combination","predictive","importance","simulations","application","illustrated","arbitrary","appearance","retrospective","typically","accessible","weighting","interpretation","analytically","properties","unfortunately","interpretability","associated","regularization","iterative","consistency","statistics","relatively","logitboost","localized","conjunction","estimators","understood","rademacher","penalized","complexities","analogues","complexity","correspondence","background","especially","circumventing","calculating","specialized","comparing","dictionaries","dictionary","candidates","semantics","gathering","classical","distributional","detecting","determining","vocabulary","available","accepting","arguments","introducing","equivalence","summarization","argumentation","constraints","processing","constraint","conditional","deterministic","exponentially","graphical","effective","representation","understanding","tractable","separately","introduces","expressing","reasoning","probabilistic","generated","classifiers","statisti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pseudolikelihood
# 	logitboost
# 	analogues
# 	collapsed
# 	preferably
# 	ellipsoid
# 	consonants
# 	cheminformatics
# 	imputations
# 	approximators
# 	cancerous
# 	multiparametric
# 	quantiles
# 	forecaster
# 	prognostics
# 	reparametrizations
# 	neighbourhood
# 	maximising
# 	metamodel
# 	oscillating
# Some words which never appear in Statistics papers:
# 	covington
# 	advancement
# 	accepting
# 	argumentation
# 	photorealistic
# 	competent
# 	extraordinary
# 	calligraphy
# 	controllability
# 	egocentric
# 	accelerator
# 	multiplexed
# 	middlebury
# 	performer
# 	extinction
# 	simplicial
# 	extractors
# 	subjected
# 	neglected
# 	anticipated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069933075458955e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
