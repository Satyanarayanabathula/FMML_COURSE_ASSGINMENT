# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyanarayanabathula/FMML_COURSE_ASSGINMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-16 04:46:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   135MB/s    in 0.5s
#
# 2023-06-16 04:46:24 (135 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21898  1502.00916v1  Inference and learning of graphical models are...  stat
# 4930   1703.03041v1  Gene and protein networks are very important t...    cs
# 2545   1602.05012v2  Recent sequential pattern mining methods have ...  stat
# 2005   1706.00074v1  Recent theoretical and experimental results su...    cs
# 35198  cs/0103020v1  We examine carefully the rationale underlying ...    cs
# ...             ...                                                ...   ...
# 10854  1502.06309v3  While machine learning has proven to be a powe...  stat
# 17758  1802.08148v1  In this paper, we describe the LIDIOMS data se...    cs
# 11042   1312.0232v4  We consider a stochastic continuum armed bandi...  stat
# 21982   1307.0323v1  The Gaussian Process Latent Variable Model (GP...  stat
# 19373   1304.4182v2  This is the Proceedings of the First Conferenc...    cs
#
#                                                    title  year  \
# 21898                       Learning Planar Ising Models  2015
# 4930   Combining Bayesian Approaches and Evolutionary...  2017
# 2545   A Subsequence Interleaving Model for Sequentia...  2016
# 2005   Free energy-based reinforcement learning using...  2017
# 35198                        Belief Revision: A Critique  2001
# ...                                                  ...   ...
# 10854  Learning with Differential Privacy: Stability,...  2015
# 17758     LIDIOMS: A Multilingual Linked Idioms Data Set  2018
# 11042  Stochastic continuum armed bandit problem of f...  2013
# 21982  Dimensionality Detection and Integration of Mu...  2013
# 19373  Proceedings of the First Conference on Uncerta...  2013
#
#                                                 keywords
# 21898  [inference, graphical, statistics, application...
# 4930   [important, molecular, inferring, reverseengin...
# 2545   [sequential, description, principle, describes...
# 2005   [theoretical, experimental, possibility, chall...
# 35198  [carefully, rationale, underlying, approaches,...
# ...                                                  ...
# 10854  [sensitive, differential, guarantees, substant...
# 17758  [multilingual, representation, currently, cont...
# 11042  [stochastic, continuum, functions, rightarrow,...
# 21982  [probabilistic, embedding, dimensional, dimens...
# 19373  [proceedings, conference, uncertainty, artific...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21898    [inference, graphical, statistics, application...
# 4930     [important, molecular, inferring, reverseengin...
# 2545     [sequential, description, principle, describes...
# 2005     [theoretical, experimental, possibility, chall...
# 35198    [carefully, rationale, underlying, approaches,...
#                                ...
# 3604     [convolutional, parameters, decompose, convolu...
# 27183    [momentsnet, convolution, nonlinear, processin...
# 14578    [discourse, generation, specifically, discours...
# 10820    [guarantees, emphasizing, overcomplete, dimens...
# 22885    [parametric, developed, assumption, sequential...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8893 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="956230e7-cf4a-4327-935f-826bf3b934dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("956230e7-cf4a-4327-935f-826bf3b934dc")) {                    Plotly.newPlot(                        "956230e7-cf4a-4327-935f-826bf3b934dc",                        [{"x":["engineering","applications","statistical","planarity","approximate","tractable","algorithm","correlations","approximation","variables","arbitrary","intractable","demonstrate","collection","techniques","embedding","application","simulations","statistics","inference","graphical","performance","approaches","specifically","overcoming","correlation","identifying","inferring","experimental","comparative","typically","combining","relationships","limitations","important","molecular","interactions","structure","complicated","analyzing","different","furthermore","evolutionary","computational","heuristics","algorithms","subsequence","efficiently","submodular","associated","expectation","principle","describes","interleaving","usefulness","maximization","optimization","sequential","structural","designing","comparable","interestingness","redundancy","compressing","interpretability","description","probabilistic","synthetic","constraint","framework","efficient","possibility","harnessing","theoretical","introduce","technique","challenging","approximating","promising","processor","reinforcement","boltzmann","configurations","processing","particularly","rationale","controversy","postulates","literature","highlight","unreasonable","observations","regarding","underlying","particular","methodological","something","carefully","attention","epistemic","additionally","condition","excellent","classification","extensions","justifying","extension","multiclass","utilizing","correcting","incentive","experiments","technologies","technology","superiority","suggestion","interface","convenient","specified","automatically","developing","suggested","suggestions","understood","challenges","especially","accurately","objective","traditional","prediction","minimization","relaxation","projected","constraints","practitioner","significant","convergence","understanding","alternating","properties","outperform","selection","frequently","nevertheless","dimensional","procedures","partially","nonparametric","preference","personalized","consistency","neighbors","neighborhood","unobserved","movielens","monotonic","completion","factorization","transformation","lipschitz","advantages","knowledge","consistent","collaborative","including","perspective","numerical","effective","denoising","hyperparameter","estimation","activities","electronic","foundations","introduction","ontologies","ontological","probability","pragmatic","conditions","corollary","empirically","verifying","dependence","sufficient","determinantal","processes","governing","illustrate","considerations","inception","functions","constrained","polynomial","initialising","contribution","strengths","generated","facilitate","supervised"],"y":[57,412,182,1,109,27,818,30,116,117,85,21,561,67,390,120,221,48,69,198,45,852,419,164,6,60,81,37,411,28,111,110,74,56,349,13,77,386,27,71,732,175,78,287,49,565,2,178,10,119,41,50,85,0,25,42,315,66,67,35,83,1,24,8,19,72,144,118,79,524,405,38,4,133,381,248,288,20,109,5,117,19,27,306,91,2,2,8,121,37,5,62,31,103,261,4,9,36,185,9,52,54,30,505,38,7,68,8,44,9,5,559,34,60,32,2,40,13,38,157,53,31,7,25,119,111,83,140,166,215,59,29,24,141,2,267,116,167,30,201,94,153,27,18,204,38,50,21,29,13,67,20,28,4,2,10,30,50,52,8,65,370,81,30,256,67,75,239,38,8,178,37,19,14,32,26,11,145,3,138,0,73,4,22,85,1,118,1,83,14,13,213,56,63,0,64,14,160,45,200],"type":"bar"},{"x":["engineering","applications","statistical","planarity","approximate","tractable","algorithm","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8308333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Comprehend</span> <span style=''>DeepWalk</span> <span style=''>as</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3506493506493506);'>Factorization</span> <br/><br/><span style=''>Word2vec</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.41040462427745666);'>representation</span> <span style=''>of</span> <span style=''>words</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3101449275362319);'>effectiveness</span> <span style=''>in</span> <span style=''>many</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>processing</span> <span style=''>tasks</span> <span style=''>Mikolov</span> <span style=''>et</span> <span style=''>al</span> <span style=''>issued</span> <span style=''>Skip</span> <span style=''>Gram</span> <span style=''>and</span> <span style=''>Negative</span> <span style=''>Sampling</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>this</span> <span style=''>toolbox</span> <span style=''>Perozzi</span> <span style=''>et</span> <span style=''>al</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>the</span> <span style=''>Skip</span> <span style=''>Gram</span> <span style=''>model</span> <span style=''>into</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>social</span> <span style=''>network</span> <span style=''>for</span> <span style=''>the</span> <span style=''>first</span> <span style=''>time</span> <span style=''>and</span> <span style=''>designed</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>named</span> <span style=''>DeepWalk</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>on</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>DeepWalk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>actually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factoring</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>M</span> <span style=''>where</span> <span style=''>each</span> <span style=''>entry</span> <span style=''>M</span> <span style=''>ij</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>that</span> <span style=''>node</span> <span style=''>i</span> <span style=''>randomly</span> <span style=''>walks</span> <span style=''>to</span> <span style=''>node</span> <span style=''>j</span> <span style=''>in</span> <span style=''>fix</span> <span style=''>steps</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Bottleneck</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>training</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Bottleneck</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimator</span> <span style=''>(BCDE)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoder</span> <span style=''>(CVAE)</span> <span style=''>that</span> <span style=''>employs</span> <span style=''>layer(s)</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottleneck</span> <span style=''>between</span> <span style=''>the</span> <span style=''>input</span> <span style=''>x</span> <span style=''>and</span> <span style=''>target</span> <span style=''>y</span> <span style=''>where</span> <span style=''>both</span> <span style=''>are</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Crucially</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>hybrid</span> <span style=''>training</span> <span style=''>method</span> <span style=''>that</span> <span style=''>blends</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>Hybrid</span> <span style=''>blending</span> <span style=''>is</span> <span style=''>the</span> <span style=''>key</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>training</span> <span style=''>of</span> <span style=''>the</span> <span style=''>BCDE</span> <span style=''>which</span> <span style=''>avoids</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>o ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Entropic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Causality</span> <span style=''>and</span> <span style=''>Greedy</span> <span style=''>Minimum</span> <span style=''>Entropy</span> <span style=''>Coupling</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>relationship</span> <span style=''>between</span> <span style=''>two</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.39845758354755784);'>variables</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.6190476190476191);'>observational</span> <span style=''>data</span> <span style=''>We</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>called</span> <span style=''>entropic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>that</span> <span style=''>works</span> <span style=''>in</span> <span style=''>a</span> <span style=''>very</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>model</span> <span style=''>but</span> <span style=''>makes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3108108108108108);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555555);'>unobserved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exogenous</span> <span style=''>variable</span> <span style=''>has</span> <span style=''>small</span> <span style=''>entropy</span> <span style=''>in</span> <span style=''>the</span> <span style=''>true</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>requires</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>entropy</span> <span style=''>coupling</span> <span style=''>problem</span> <span style=''>Given</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.33529411764705874);'>distributions</span> <span style=''>of</span> <span style=''>m</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.39845758354755784);'>variables</span> <span style=''>each</span> <span style=''>on</span> <span style=''>n</span> <span style=''>states</span> <span style=''>find</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>with</span> <span style=''>minimum</span> <span style=''>entropy</span> <span style=''>that</span> <span style=''>respects</span> <span style=''>the</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginals</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>a</span> <span style=''>concave</span> <span style=''>function</span> <span style=''>of</span> <span style=''>nm</span> <span style='background-color:rgba(255, 0, 0, 0.39845758354755784);'>variables</span> <span style=''>over</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>polytope</span> <span style=''>defined</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Knowledge</span> <span style=''>Gradient</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Batch</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>one</span> <span style=''>can</span> <span style=''>evaluate</span> <span style=''>multiple</span> <span style=''>points</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>eg</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performances</span> <span style=''>of</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>in</span> <span style=''>a</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>batch</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>this</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>the</span> <span style=''>one</span> <span style=''>step</span> <span style=''>Bayes</span> <span style=''>optimal</span> <span style=''>batch</span> <span style=''>of</span> <span style=''>points</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>strategy</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>this</span> <span style=''>Bayes</span> <span style=''>optimal</span> <span style=''>batch</span> <span style=''>of</span> <span style=''>points</span> <span style=''>and</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>finds</span> <span style=''>global</span> <span style=''>optima</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>previous</span> <span style=''>batch</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>on</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>test</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08834048640915594)
# 	representation (0.13090128755364808)
# 	knowledge (0.1323319027181688)
# 	processing (0.10944206008583691)
# 	experimental (0.14699570815450644)
# 	detection (0.12839771101573677)
# 	information (0.2592989985693848)
# 	different (0.26180257510729615)
# 	recognition (0.1251788268955651)
# 	convolutional (0.13197424892703863)
#
# Some Statistics words are:
# 	stochastic (0.1312375249500998)
# 	statistical (0.15219560878243513)
# 	variables (0.13572854291417166)
# 	theoretical (0.14920159680638723)
# 	algorithm (0.3967065868263473)
# 	distribution (0.18063872255489022)
# 	estimation (0.1721556886227545)
# 	dimensional (0.18962075848303392)
# 	inference (0.20209580838323354)
# 	regression (0.17664670658682635)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="34de715b-fa9c-47b8-9be4-94966af77feb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34de715b-fa9c-47b8-9be4-94966af77feb")) {                    Plotly.newPlot(                        "34de715b-fa9c-47b8-9be4-94966af77feb",                        [{"x":["engineering","applications","statistical","planarity","approximate","tractable","algorithm","correlations","approximation","variables","arbitrary","intractable","demonstrate","collection","techniques","embedding","application","simulations","statistics","inference","graphical","performance","approaches","specifically","overcoming","correlation","identifying","inferring","experimental","comparative","typically","combining","relationships","limitations","important","molecular","interactions","structure","complicated","analyzing","different","furthermore","evolutionary","computational","heuristics","algorithms","subsequence","efficiently","submodular","associated","expectation","principle","describes","interleaving","usefulness","maximization","optimization","sequential","structural","designing","comparable","interestingness","redundancy","compressing","interpretability","description","probabilistic","synthetic","constraint","framework","efficient","possibility","harnessing","theoretical","introduce","technique","challenging","approximating","promising","processor","reinforcement","boltzmann","configurations","processing","particularly","rationale","controversy","postulates","literature","highlight","unreasonable","observations","regarding","underlying","particular","methodological","something","carefully","attention","epistemic","additionally","condition","excellent","classification","extensions","justifying","extension","multiclass","utilizing","correcting","incentive","experiments","technologies","technology","superiority","suggestion","interface","convenient","specified","automatically","developing","suggested","suggestions","understood","challenges","especially","accurately","objective","traditional","prediction","minimization","relaxation","projected","constraints","practitioner","significant","convergence","understanding","alternating","properties","outperform","selection","frequently","nevertheless","dimensional","procedures","partially","nonparametric","preference","personalized","consistency","neighbors","neighborhood","unobserved","movielens","monotonic","completion","factorization","transformation","lipschitz","advantages","knowledge","consistent","collaborative","including","perspective","numerical","effective","denoising","hyperparameter","estimation","activities","electronic","foundations","introduction","ontologies","ontological","probability","pragmatic","conditions","corollary","empirically","verifying","dependence","sufficient","determinantal","processes","governing","illustrate","considerations","inception","functions","constrained","polynomial","initialising","contribution","strengths","generated","facilitate","supervised","variational","representation","recurrent","unlabeled","unsupervised","generative","predictions","beforehand","simulating","development","environment","operational","experience","monetization","forecasting","successful","developers","engagement","behaviors","fundamental","simulation","production","behavioral","purchases","unfortunately","parameter","possibilities","recommender","financial","biological","computationally","regularized","marginally","likelihood","conditionally","complement","covariance","statistically","developed","convergent","implementation","available","multilabel","specialized","components","objectives","identification","technical","complexity","resulting","generalizing","component","nonsmooth","quadratic","direction","regulariz ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interleaving
# 	corollary
# 	initialising
# 	monetization
# 	purchases
# 	marginally
# 	prohibits
# 	solvation
# 	decontamination
# 	ultrahigh
# 	equitability
# 	criticized
# 	similitude
# 	oscillates
# 	stabilisation
# 	depression
# 	disability
# 	disaggregation
# 	appliance
# 	inspecting
# Some words which never appear in Statistics papers:
# 	controversy
# 	postulates
# 	ontological
# 	discontinuous
# 	transcriptions
# 	photographs
# 	stylistic
# 	photographic
# 	characterised
# 	creativity
# 	descriptive
# 	reflective
# 	substitutions
# 	omnidirectional
# 	perceptually
# 	observers
# 	pathologists
# 	grassmann
# 	homography
# 	activitynet

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074841645655249e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775
